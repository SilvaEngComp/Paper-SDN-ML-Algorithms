# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading data

# %%
print('loading dataset')
dataset = pd.read_csv('../data.txt', delimiter=" ")
subset  = dataset[(dataset["moteid"] >=2)]
subset  = subset[(subset["moteid"] <=6)]

subset
# Out:
# loading dataset
#               date             time  epoch  moteid  temperature  humidity  \
# 43047   2004-04-01  04:34:48.130427      2     2.0      89.5488  29.25810
# 43048   2004-02-28  01:08:16.776717     21     2.0      19.5670  39.68780
# 43049   2004-02-28  01:10:16.105455     25     2.0      19.5376  39.75570
# 43050   2004-02-28  01:26:46.606579     58     2.0      19.4788  39.68780
# 43051   2004-02-28  01:28:16.345812     61     2.0      19.4494  39.72170
# ...            ...              ...    ...     ...          ...       ...
# 216085  2004-03-21  18:56:25.346614  65516     6.0     122.1530  -3.91901
# 216086  2004-03-21   18:57:25.25367  65518     6.0     122.1530  -3.91901
# 216087  2004-03-21  19:00:28.406251  65524     6.0     122.1530  -3.91901
# 216088  2004-03-21  19:01:58.106417  65527     6.0     122.1530  -3.91901
# 216089  2004-03-21  19:04:34.513672  65532     6.0     122.1530  -3.91901
#
#          light  voltage
# 43047    11.96  1.95368
# 43048   121.44  2.67532
# 43049   121.44  2.67532
# 43050   121.44  2.66332
# 43051   121.44  2.67532
# ...        ...      ...
# 216085    5.52  2.24970
# 216086    5.52  2.24970
# 216087    5.52  2.24970
# 216088    5.52  2.24970
# 216089    1.38  2.24970
#
# [173043 rows x 8 columns]

# %%
subset.drop(['date','time'], axis=1, inplace=True)

scaler = StandardScaler().fit(subset)

# %%
#separa os datasets
print('separing dataset')
test  = subset[(subset["moteid"] <=2)]
train  = subset[subset["moteid"] > 2]
# Out:
# separing dataset

# %%
norm_subset = pd.DataFrame(scaler.transform(train), columns = train.columns)

# %%
train = train[train['temperature']<26]
train = train[train['temperature']>15]

test = test[test['temperature']<26]
test = test[test['temperature']>15]

# %%
norm_subset = pd.DataFrame(scaler.transform(train), columns = train.columns)

# %%
ax = sns.boxplot(data=norm_subset, orient="h", palette="Set2")

# %%
# ax = sns.boxplot(data=train['temperature'], orient="h", palette="Set2")

# %%
train["temperature"].plot.hist(grid=True, bins=10, rwidth=0.9,
                   color='#607c8e')
plt.title("Attribute: temperature")
# Out:
# Text(0.5, 1.0, 'Attribute: temperature')

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(train)
norm_subset = pd.DataFrame(scaler.transform(train), columns = train.columns)
ax = sns.boxplot(data=norm_subset, orient="h", palette="Set2")

# ax = sns.boxplot(data=train['temperature'], orient="h", palette="Set2")

train["temperature"].plot.hist(grid=True, bins=10, rwidth=0.9,
                   color='#607c8e')
plt.title("Attribute: temperature")# train.index = train['timestamp']
# Out:
# Text(0.5, 1.0, 'Attribute: temperature')

# %% [markdown]
# # general graphic

# %%
 ax = sns.boxplot(data=train, orient="h", palette="Set2")

# %% [markdown]
# # Normalized Graphic

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler().fit(train)
norm_subset = pd.DataFrame(scaler.transform(train), columns = train.columns)
ax = sns.boxplot(data=norm_subset, orient="h", palette="Set2")

# %%
# ax = sns.boxplot(data=train['temperature'], orient="h", palette="Set2")

# %%
train["temperature"].plot.hist(grid=True, bins=10, rwidth=0.9,
                   color='#607c8e')
plt.title("Attribute: temperature")
# Out:
# Text(0.5, 1.0, 'Attribute: temperature')

# %%
# train["delay"].plot.hist(grid=True, bins=10, rwidth=0.9,
#                    color='#607c8e')
# plt.title("Attribute: delay")

# %%
train.corr()
# Out:
#                 epoch    moteid  temperature  humidity     light   voltage
# epoch        1.000000 -0.081883     0.214011  0.317183 -0.024107 -0.863513
# moteid      -0.081883  1.000000    -0.032150 -0.027353  0.391799 -0.076977
# temperature  0.214011 -0.032150     1.000000 -0.413709  0.284995  0.040216
# humidity     0.317183 -0.027353    -0.413709  1.000000 -0.161912 -0.488095
# light       -0.024107  0.391799     0.284995 -0.161912  1.000000  0.025676
# voltage     -0.863513 -0.076977     0.040216 -0.488095  0.025676  1.000000

# %%
corr = train.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
plt.title("Line graph")  
plt.xlabel("X axis")  
plt.ylabel("Y axis")  
plt.plot(np.arange(len(train[train.temperature<30].temperature)), train.temperature, color ="purple")  
plt.show()

# %%
plt.title("Line graph")  
plt.xlabel("X axis")  
plt.ylabel("Y axis")  
plt.plot(np.arange(len(test.temperature)), test.temperature, color ="purple")  
plt.show()
