# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import seaborn as sns
import csv

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from threading import Timer
from timeit import default_timer as timer
from IPython.display import clear_output

# %%
start = timer()
prep_dataset1 = pd.read_csv('datasets/com_concept_drift/sdn_train_unormalized1.csv', delimiter=",")
prep_dataset2 = pd.read_csv('datasets/com_concept_drift/sdn_train_unormalized2.csv', delimiter=",")
prep_dataset3 = pd.read_csv('datasets/com_concept_drift/sdn_train_unormalized3.csv', delimiter=",")
prep_test = pd.read_csv('datasets/com_concept_drift/sdn_test_unormalized.csv', delimiter=",")

# %% [markdown]
# # Normalizing

# %%
def normalizing(df):
    f_columns = ['temperature','label']
    scaler1 = StandardScaler().fit(df)
    scaler2 = StandardScaler().fit(df)

    scaler1= scaler1.fit(df[f_columns].to_numpy())
    scaler2 = scaler2.fit(df[['delay']])

    df.loc[:,f_columns] = scaler1.transform(df[f_columns].to_numpy())
    df['delay'] = scaler2.transform(df[['delay']])
    return df


def unormalizing(df,Y_test,y_pred ):
    scaler = StandardScaler().fit(df)
    scaler = scaler.fit(df[['delay']])
    y_test_inv = scaler.inverse_transform(Y_test.reshape(1,-1))
    y_pred_inv = scaler.inverse_transform(y_pred)
    
    return y_test_inv, y_pred_inv

# %%
def saveFile(dataset, name='dataset'):
    print('saving: ',name, '......')
    f = open(name,'w')
    try:
        writer = csv.writer(f)
        writer.writerow(dataset.columns)
        for i in np.arange(int(dataset.shape[0])):
            writer.writerow(dataset.iloc[i,])
    finally:
        f.close()
        

def preprocessing(dataset, order): 
    window = 20
    cont = 0;
    cols = ['timestamp','temperature','label' ,'delay' ]
    newSet = []
    while(cont<dataset.shape[0]):
        MyLIst = dataset.iloc[cont:cont+window,:]
        cont+=20
        deltaT = np.max(MyLIst.temperature) - np.min(MyLIst.temperature)
        deltaTime = np.max(MyLIst.seconds) - np.min(MyLIst.seconds)
        meanDelay = np.mean(MyLIst.delay)
        label=MyLIst.iloc[0,3]   
        newSet.append([deltaTime,deltaT,label,meanDelay])
    delta_df = pd.DataFrame(np.array(newSet), columns = cols)
    saveFile(delta_df, 'datasets/delta/sdn_train_mininet_unormalized_'+order+'.csv')
    norm = normalizing(delta_df)
    saveFile(norm, 'datasets/delta/sdn_train_mininet_normalized_'+order+'.csv')

    return norm

# %%
def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []    
    for i in range(len(X) - time_steps):
        clear_output(wait=True)
        print('modeling to keras ',round((i/(len(X) - time_steps))*100,2), ('%'), end='')
        s = round(timer() - start)
        if(s>60):
            s /=60
            print(' ', s, ' seconds')
        v = X.iloc[i: (i+time_steps), 0:3].to_numpy()
        Xs.append(v)
        ys.append(y.iloc[i+time_steps])
    return np.array(Xs), np.array(ys)

# %%
preprocessing(prep_dataset1, '1')
preprocessing(prep_dataset2, '2')
preprocessing(prep_dataset3, '3')
preprocessing(prep_test, 'test')
# Out:
# saving:  datasets/delta/sdn_train_mininet_unormalized_1.csv ......
# saving:  datasets/delta/sdn_train_mininet_normalized_1.csv ......
# saving:  datasets/delta/sdn_train_mininet_unormalized_2.csv ......
# saving:  datasets/delta/sdn_train_mininet_normalized_2.csv ......
# saving:  datasets/delta/sdn_train_mininet_unormalized_3.csv ......
# saving:  datasets/delta/sdn_train_mininet_normalized_3.csv ......
# saving:  datasets/delta/sdn_train_mininet_unormalized_test.csv ......
# saving:  datasets/delta/sdn_train_mininet_normalized_test.csv ......
#       timestamp  temperature     label     delay
# 0        3030.0     2.855213 -0.098934 -0.046209
# 1        1740.0    -0.192323 -0.098934 -0.046209
# 2        1320.0    -0.275437 -0.098934 -0.046209
# 3        1590.0    -0.303142 -0.098934 -0.046209
# 4        1500.0    -0.303142 -0.098934 -0.046209
# ...         ...          ...       ...       ...
# 1233     2583.0     0.250955 -0.098934 -0.046209
# 1234     3007.0     0.306365 -0.098934 -0.046209
# 1235     2910.0     0.638823 -0.098934 -0.046209
# 1236     2909.0     0.888167 -0.098934 -0.046209
# 1237     1859.0    -0.026094 -0.098934 -0.046209
#
# [1238 rows x 4 columns]

# %%
def LSTMconf(X_train):
    print('Init config LSTM')
    model = keras.Sequential()
    model.add(
        keras.layers.Bidirectional(
            keras.layers.LSTM(
                 activation="relu",
                units=40,
                input_shape=(X_train.shape[1],X_train.shape[2])
            )
        ))
    model.add(keras.layers.Dense(units=40, activation="relu"))
    model.add(keras.layers.Dense(units=40, activation="relu"))
    model.add(keras.layers.Dense(units=40, activation="relu"))
    model.add(keras.layers.Dense(units=40, activation="relu"))
    model.add(keras.layers.Dropout(rate=0.2))
    model.add(keras.layers.Dense(units=1))
    
    loss ="mse"
    optim = tf.keras.optimizers.Adam(
    learning_rate=0.0001)
    metrics=["accuracy"]

    model.compile(loss=loss, optimizer=optim, 
             metrics=metrics
             )
    return model

# %%
def LSTMfit(model,X_train,Y_train):
    print('Init Train')
    start = timer()
    history = model.fit(
        X_train, Y_train, 
        epochs=100, 
        batch_size= 10,
        validation_split=0.25,
        shuffle=False,
    #     callbacks=[tensorboard_callback]
    )
    return history

# %%
model = None
for i in range(1,4):
    train = pd.read_csv('datasets/delta/sdn_train_mininet_normalized_'+str(i)+'.csv', delimiter=",")     
    X_train,Y_train = create_dataset(train, train.delay)
    if(model is None):
        model = LSTMconf(X_train)
    history = LSTMfit(model,X_train, Y_train)

# r = Timer(1.0, preprocessing, (prep_dataset.iloc[cont:cont+window,:]))
# r.start()
# print(X_train)
# Out:
# modeling to keras  99.94 %  16.9  seconds
# Init Train
# Epoch 1/100
# 116/116 [==============================] - 1s 4ms/step - loss: 1.3351 - accuracy: 0.0000e+00 - val_loss: 6.3182e-05 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 116/116 [==============================] - 0s 4ms/step - loss: 1.3349 - accuracy: 0.0000e+00 - val_loss: 1.1848e-04 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 116/116 [==============================] - 0s 3ms/step - loss: 1.3347 - accuracy: 0.0000e+00 - val_loss: 1.6181e-04 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 116/116 [==============================] - 0s 3ms/step - loss: 1.3347 - accuracy: 0.0000e+00 - val_loss: 1.9357e-04 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 116/116 [==============================] - 0s 3ms/step - loss: 1.3346 - accuracy: 0.0000e+00 - val_loss: 2.1067e-04 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 116/116 [==============================] - 0s 3ms/step - loss: 1.3346 - accuracy: 0.0000e+00 - val_loss: 2.4231e-04 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 116/116 [==============================] - 0s 3ms/step - loss: 1.3346 - accuracy: 0.0000e+00 - val_loss: 2.8090e-04 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 116/116 [==============================] - 0s 3ms/step - loss: 1.3345 - accuracy: 0.0000e+00 - val_loss: 3.2204e-04 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 116/116 [==============================] - 0s 4ms/step - loss: 1.3345 - accuracy: 0.0000e+00 - val_loss: 3.5938e-04 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 116/116 [==============================] - 0s 3ms/step - loss: 1.3344 - accuracy: 0.0000e+00 - val_loss: 3.7744e-04 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 116/116 [==============================] - 0s 3ms/step - loss: 1.3343 - accuracy: 0.0000e+00 - val_loss: 4.5443e-04 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 116/116 [==============================] - 0s 3ms/step - loss: 1.3342 - accuracy: 0.0000e+00 - val_loss: 3.8392e-04 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 116/116 [==============================] - 0s 3ms/step - loss: 2.0654 - accuracy: 0.0000e+00 - val_loss: 0.4547 - val_accuracy: 0.0000e+00
# Epoch 14/100
#
- accuracy: 0.0000e+00 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 57/100
# 116/116 [==============================] - 0s 3ms/step - loss: 1.4238 - accuracy: 0.0000e+00 - val_loss: 6.2068e-04 - val_accuracy: 0.0000e+00
# Epoch 58/100
# 116/116 [==============================] - 0s 4ms/step - loss: 1.4919 - accuracy: 0.0000e+00 - val_loss: 0.0021 - val_accuracy: 0.0000e+00
# Epoch 59/100
# 116/116 [==============================] - 1s 4ms/step - loss: 1.4356 - accuracy: 0.0000e+00 - val_loss: 0.0013 - val_accuracy: 0.0000e+00
# Epoch 60/100
# 116/116 [==============================] - 0s 4ms/step - loss: 1.6373 - accuracy: 0.0000e+00 - val_loss: 8.8818e-04 - val_accuracy: 0.0000e+00
# Epoch 61/100
# 116/116 [==============================] - 0s 4ms/step - loss: 1.8983 - accuracy: 0.0000e+00 - val_loss: 0.0065 - val_accuracy: 0.0000e+00
# Epoch 62/100
# 116/116 [==============================] - 0s 4ms/step - loss: 1.8950 - accuracy: 0.0000e+00 - val_loss: 9.7645e-04 - val_accuracy: 0.0000e+00
# Epoch 63/100
# 116/116 [==============================] - 0s 3ms/step - loss: 1.5331 - accuracy: 0.0000e+00 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 64/100
# 116/116 [==============================] - 0s 4ms/step - loss: 1.5933 - accuracy: 0.0000e+00 - val_loss: 6.6716e-04 - val_accuracy: 0.0000e+00
# Epoch 65/100
# 116/116 [==============================] - 0s 4ms/step - loss: 1.4682 - accuracy: 0.0000e+00 - val_loss: 0.0036 - val_accuracy: 0.0000e+00
# Epoch 66/100
# 116/116 [==============================] - 0s 3ms/step - loss: 1.9577 - accuracy: 0.0000e+00 - val_loss: 5.1164e-04 - val_accuracy: 0.0000e+00
# Epoch 67/100
# 116/116 [==============================] - 0s 3ms/step - loss: 1.4068 - accuracy: 0.0000e+00 - val_loss: 9.3121e-04 - val_accuracy: 0.0000e+00
# Epoch 68/100
# 116/116 [==============================] - 0s 4ms/step - loss: 1.3845 - accuracy: 0.0000e+00 - val_loss: 7.2361e-04 - val_accuracy: 0.0000e+00
# Epoch 69/100
# 116/116 [==============================] - 0s 3ms/step - loss: 1.3679 - accuracy: 0.0000e+00 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 70/100
# 116/116 [==============================] - 0s 3ms/step - loss: 1.3762 - accuracy: 0.0000e+00 - val_loss: 7.6123e-04 - val_accuracy: 0.0000e+00
# Epoch 71/100
# 116/116 [==============================] - 0s 3ms/step - loss: 1.5102 - accuracy: 0.0000e+00 - val_loss: 0.0013 - val_accuracy: 0.0000e+00
# Epoch 72/100
#  77/116 [==================>...........] - ETA: 0s - loss: 2.0605 - accuracy: 0.0000e+00

# %%
print('Saving Model')
model.save('models/lstm')

# %% [markdown]
# # loss training

# %%
fig1 = plt.figure()
ax1 = fig1.add_subplot(1,1,1)
ax1.plot(history.history['loss'], label='train')
ax1.plot(history.history['val_loss'], label='validation')
ax1.legend();

# %%
test = pd.read_csv('datasets/delta/sdn_train_mininet_normalized_test.csv', delimiter=",")     
X_test,Y_test = create_dataset(test, test.delay)

# %% [markdown]
# # predicting

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# # unormalizing

# %%
y_test_inv, y_pred_inv = unormalizing(test, Y_test, y_pred)

# %%
fig2 = plt.figure()
a2 = fig2.add_subplot(1,1,1)
a2.plot(y_test_inv.flatten(), marker='.', label='true')
a2.legend();

# %%
fig3 = plt.figure()
a3 = fig3.add_subplot(1,1,1)
a3.plot(y_pred_inv.flatten(),'r',marker='.', label='predicted')
a3.legend();

# %%
fig4 = plt.figure()
a4 = fig4.add_subplot(1,1,1)

a4.plot(y_test_inv.flatten(), marker='.', label='true')
a4.plot(y_pred_inv.flatten(),'r',marker='.', label='predicted')
a4.legend();

# %%
l1 = []
l2 = []
for i in np.arange(y_pred_inv.shape[0]):
    clear_output(wait=True)
    print('progress ',round((i/y_pred_inv.shape[0])*100,2), ('%'))
    if(y_pred_inv[i,0]<=10):
        l1.append(y_pred_inv[i,0])
    if(y_test_inv[0,i]<=10):
        l2.append(y_test_inv[0,i])

y_pred_inv2 = np.array(l1)
y_test_inv2 = np.array(l2)

# %%
plt.plot(y_pred_inv2.flatten(),'r',marker='.', label='predicted')
plt.plot(y_test_inv2.flatten(), marker='.', label='true')
plt.legend();

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_log_error

# %%
rmse =  mean_squared_error(y_test_inv2, y_pred_inv2[0:73797], squared=False)
mae =  mean_absolute_error(y_test_inv2, y_pred_inv2[0:73797])
median_mae = median_absolute_error(y_test_inv2, y_pred_inv2[0:73797])
msle = mean_squared_log_error(y_test_inv2, y_pred_inv2[0:73797])

print(rmse)
print(mae)
print(median_mae)

# %%
objects = ('rmse', 'mae', 'median-mae')
y_pos = np.arange(3)
performance = [rmse,mae,median_mae]

plt.bar(y_pos, performance, align='center')
plt.xticks(y_pos, objects)
#plt.ylabel('Usage')
plt.title('Métricas regressão')

plt.show()

# %%
objects = ('msle')
y_pos = np.arange(2)
performance = [msle]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
#plt.ylabel('Usage')
plt.title('Métricas regressão')

plt.show()
